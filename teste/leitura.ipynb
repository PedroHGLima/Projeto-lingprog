# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('Covid Live.csv')
df.head()
# Out:
#    # Country, Other Total Cases Total Deaths  New Deaths Total Recovered  \
# 0  1            USA  98,166,904    1,084,282         NaN      94,962,112
# 1  2          India  44,587,307      528,629         NaN      44,019,095
# 2  3         France  35,342,950      155,078         NaN      34,527,115
# 3  4         Brazil  34,706,757      686,027         NaN      33,838,636
# 4  5        Germany  33,312,373      149,948         NaN      32,315,200
#
#   Active Cases Serious, Critical Tot Cases/1M pop Deaths/1M pop  \
# 0    2,120,510             2,970          293,206         3,239
# 1       39,583               698           31,698           376
# 2      660,757               869          538,892         2,365
# 3      182,094             8,318          161,162         3,186
# 4      847,225             1,406          397,126         1,788
#
#      Total Tests Tests/1M pop     Population
# 0  1,118,158,870    3,339,729    334,805,269
# 1    894,416,853      635,857  1,406,631,776
# ...

# %%
df['Total Cases'] = df['Total Cases'].str.replace(',', '').astype(float)
df['Total Deaths'] = df['Total Deaths'].str.replace(',', '').astype(float)
df['Total Recovered'] = df['Total Recovered'].str.replace(',', '').astype(float)
df['Active Cases'] = df['Active Cases'].str.replace(',', '').astype(float)
df['Serious, Critical'] = df['Serious, Critical'].str.replace(',', '').astype(float)
df['Tot Cases/1M pop'] = df['Tot Cases/1M pop'].str.replace(',', '').astype(float)
df['Deaths/1M pop'] = df['Deaths/1M pop'].str.replace(',', '').astype(float)
df['Total Tests'] = df['Total Tests'].str.replace(',', '').astype(float)
df['Tests/1M pop'] = df['Tests/1M pop'].str.replace(',', '').astype(float)
df['Population'] = df['Population'].str.replace(',', '').astype(float)

# %%
most_cases = df.sort_values(by='Total Cases', ascending=False).head(10)
most_cases
# Out:
#     # Country, Other  Total Cases  Total Deaths  New Deaths  Total Recovered  \
# 0   1            USA   98166904.0     1084282.0         NaN       94962112.0
# 1   2          India   44587307.0      528629.0         NaN       44019095.0
# 2   3         France   35342950.0      155078.0         NaN       34527115.0
# 3   4         Brazil   34706757.0      686027.0         NaN       33838636.0
# 4   5        Germany   33312373.0      149948.0         NaN       32315200.0
# 5   6       S. Korea   24769101.0       28406.0        42.0       24013461.0
# 6   7             UK   23621952.0      189919.0         NaN       23347871.0
# 7   8          Italy   22432803.0      177054.0         NaN       21779604.0
# 8   9          Japan   21229216.0       44678.0         NaN       20380089.0
# 9  10         Russia   20948470.0      387163.0         NaN       19979763.0
#
#    Active Cases  Serious, Critical  Tot Cases/1M pop  Deaths/1M pop  \
# ...

# %%
num = 3
most_deaths = df.sort_values(by='Total Deaths', ascending=False)
most_deaths['Country, Other'].iloc[:num]
# Out:
# 0       USA
# 3    Brazil
# 1     India
# Name: Country, Other, dtype: object

# %%
most_pop = df.sort_values(by='Population', ascending=False).head(10)
most_pop
# Out:
#        # Country, Other  Total Cases  Total Deaths  New Deaths  \
# 107  108          China     250449.0        5226.0         NaN
# 1      2          India   44587307.0      528629.0         NaN
# 0      1            USA   98166904.0     1084282.0         NaN
# 18    19      Indonesia    6429767.0      158093.0         NaN
# 52    53       Pakistan    1572598.0       30616.0         3.0
# 105  106        Nigeria     265382.0        3155.0         NaN
# 3      4         Brazil   34706757.0      686027.0         NaN
# 44    45     Bangladesh    2024489.0       29362.0         NaN
# 9     10         Russia   20948470.0      387163.0         NaN
# 17    18         Mexico    7084488.0      330065.0         NaN
#
#      Total Recovered  Active Cases  Serious, Critical  Tot Cases/1M pop  \
# 107         242254.0        2969.0               36.0             173.0
# 1         44019095.0       39583.0              698.0           31698.0
# ...
